# %% [markdown]
# # Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings;
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load the data in python env

# %%
cabs_data = pd.read_csv('YourCabs.csv')
cabs_data
# Out:
#            id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 0      132512    22177                28         NaN               2
# 1      132513    21413                12         NaN               2
# 2      132514    22178                12         NaN               2
# 3      132515    13034                12         NaN               2
# 4      132517    22180                12         NaN               2
# ...       ...      ...               ...         ...             ...
# 43426  185937    14364                12         NaN               2
# 43427  185938    48727                12         NaN               2
# 43428  185939    48729                12         1.0               3
# 43429  185940    30724                87         NaN               2
# 43430  185941    48730                12         NaN               2
#
#        from_area_id  to_area_id  from_city_id  to_city_id         from_date  \
# ...

# %%
cabs_data.head()
# Out:
#        id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 0  132512    22177                28         NaN               2
# 1  132513    21413                12         NaN               2
# 2  132514    22178                12         NaN               2
# 3  132515    13034                12         NaN               2
# 4  132517    22180                12         NaN               2
#
#    from_area_id  to_area_id  from_city_id  to_city_id         from_date  \
# 0          83.0       448.0           NaN         NaN  01-01-2013 02:00
# 1        1010.0       540.0           NaN         NaN  01-01-2013 09:00
# 2        1301.0      1034.0           NaN         NaN  01-01-2013 03:30
# 3         768.0       398.0           NaN         NaN  01-01-2013 05:45
# 4        1365.0       849.0           NaN         NaN  01-01-2013 09:00
#
#    online_booking  mobile_site_booking   booking_created   from_lat  \
# 0               0                    0  01-01-2013 01:39  12.924150
# ...

# %% [markdown]
# # Verify the data

# %%
# Display information about the cabs_data DataFrame

cabs_data.info
# Out:
# <bound method DataFrame.info of            id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 0      132512    22177                28         NaN               2
# 1      132513    21413                12         NaN               2
# 2      132514    22178                12         NaN               2
# 3      132515    13034                12         NaN               2
# 4      132517    22180                12         NaN               2
# ...       ...      ...               ...         ...             ...
# 43426  185937    14364                12         NaN               2
# 43427  185938    48727                12         NaN               2
# 43428  185939    48729                12         1.0               3
# 43429  185940    30724                87         NaN               2
# 43430  185941    48730                12         NaN               2
#
#        from_area_id  to_area_id  from_city_id  to_city_id         from_date  \
# ...

# %%
# Display the shape of the cabs_data DataFrame
cabs_data.shape
# Out:
# (43431, 18)

# %%
# Display descriptive statistics for the cabs_data DataFrame

cabs_data.describe()
# Out:
#                   id       user_id  vehicle_model_id   package_id  \
# count   43431.000000  43431.000000       43431.00000  7550.000000
# mean   159206.473556  30739.198153          25.71723     2.030066
# std     15442.386279  10996.476709          26.79825     1.461756
# min    132512.000000     16.000000           1.00000     1.000000
# 25%    145778.000000  24614.000000          12.00000     1.000000
# 50%    159248.000000  31627.000000          12.00000     2.000000
# 75%    172578.500000  39167.000000          24.00000     2.000000
# max    185941.000000  48730.000000          91.00000     7.000000
#
#        travel_type_id  from_area_id    to_area_id  from_city_id   to_city_id  \
# count    43431.000000  43343.000000  34293.000000  16345.000000  1588.000000
# mean         2.137252    714.544494    669.490917     14.915081    68.537783
# std          0.437712    419.883553    400.638225      1.165306    49.880732
# ...

# %%
# Display descriptive statistics for object-type columns in the cabs_data DataFrame

cabs_data.describe(include='object')
# Out:
#                from_date   booking_created
# count              43431             43431
# unique             20377             39349
# top     10-12-2013 06:00  10/31/2013 10:30
# freq                  20                18

# %%
# Finding out the null values
cabs_data.isnull().sum()
# Out:
# id                         0
# user_id                    0
# vehicle_model_id           0
# package_id             35881
# travel_type_id             0
# from_area_id              88
# to_area_id              9138
# from_city_id           27086
# to_city_id             41843
# from_date                  0
# online_booking             0
# mobile_site_booking        0
# booking_created            0
# from_lat                  93
# from_long                 93
# to_lat                  9138
# to_long                 9138
# Car_Cancellation           0
# dtype: int64

# %% [markdown]
# # if our travel type id is 1 means long distance travelling then we required only from are id

# %% [markdown]
# So we  consider only necessary column regarding to long distance travelling

# %%
# List of columns to drop from the DataFrame

columns_to_drop = ['to_city_id','to_area_id','id','user_id','vehicle_model_id','package_id',"booking_created", 'from_city_id',  'from_lat',"from_date", 'from_long', 'to_lat', 'to_long']
cabs_data.drop(columns=columns_to_drop,axis=1, inplace=True)

# %%
cabs_data
# Out:
#        travel_type_id  from_area_id  online_booking  mobile_site_booking  \
# 0                   2          83.0               0                    0
# 1                   2        1010.0               0                    0
# 2                   2        1301.0               0                    0
# 3                   2         768.0               0                    0
# 4                   2        1365.0               0                    0
# ...               ...           ...             ...                  ...
# 43426               2        1147.0               1                    0
# 43427               2         393.0               1                    0
# 43428               3         974.0               0                    0
# 43429               2        1263.0               0                    0
# 43430               2         689.0               0                    1
#
#        Car_Cancellation
# 0                     0
# 1                     0
# ...

# %%
# Assuming your DataFrame is named cabs_data_newtest
filtered_data = cabs_data[cabs_data['travel_type_id'] == 1]

# Display the shape and head of the filtered DataFrame
print(filtered_data.shape)
print(filtered_data.head())
# Out:
# (1589, 5)
#      travel_type_id  from_area_id  online_booking  mobile_site_booking  \
# 6                 1         571.0               0                    0
# 17                1        1383.0               1                    0
# 24                1         515.0               0                    0
# 158               1         136.0               1                    0
# 216               1        1118.0               1                    0
#
#      Car_Cancellation
# 6                   0
# 17                  0
# 24                  0
# 158                 0
# 216                 0

# %%
filtered_data
# Out:
#        travel_type_id  from_area_id  online_booking  mobile_site_booking  \
# 6                   1         571.0               0                    0
# 17                  1        1383.0               1                    0
# 24                  1         515.0               0                    0
# 158                 1         136.0               1                    0
# 216                 1        1118.0               1                    0
# ...               ...           ...             ...                  ...
# 43342               1         393.0               1                    0
# 43385               1         119.0               1                    0
# 43386               1        1281.0               1                    0
# 43393               1         393.0               0                    0
# 43407               1        1180.0               0                    0
#
#        Car_Cancellation
# 6                     0
# 17                    0
# ...

# %%
filtered_data.dropna()
# Out:
#        travel_type_id  from_area_id  online_booking  mobile_site_booking  \
# 6                   1         571.0               0                    0
# 17                  1        1383.0               1                    0
# 24                  1         515.0               0                    0
# 158                 1         136.0               1                    0
# 216                 1        1118.0               1                    0
# ...               ...           ...             ...                  ...
# 43342               1         393.0               1                    0
# 43385               1         119.0               1                    0
# 43386               1        1281.0               1                    0
# 43393               1         393.0               0                    0
# 43407               1        1180.0               0                    0
#
#        Car_Cancellation
# 6                     0
# 17                    0
# ...

# %% [markdown]
# # Splitting the data into train and test sets

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
print(X_train.shape)
X_train.head()
# Out:
# (1050, 4)
#        travel_type_id  from_area_id  online_booking  mobile_site_booking
# 21037               1         393.0               1                    0
# 15354               1         571.0               0                    0
# 18384               1        1312.0               1                    0
# 18637               1        1136.0               1                    0
# 36482               1         789.0               0                    0

# %%
print(y_train.shape)
y_train.head()
# Out:
# (451, 4)
#        travel_type_id  from_area_id  online_booking  mobile_site_booking
# 13231               1        1147.0               0                    0
# 332                 1         396.0               0                    0
# 43407               1        1180.0               0                    0
# 1520                1         293.0               0                    0
# 22708               1         458.0               0                    0

# %%
print(X_test.shape)
X_test.head()

# %%
print(y_test.shape)
y_test.tail()

# %%
filtered_data.isnull().sum()

# %%
# Drop rows with null values from the original DataFrame in-place
filtered_data.dropna(inplace=True)

# Check for null values again
print(filtered_data.isnull().sum())
# Out:
# travel_type_id         0
# from_area_id           0
# online_booking         0
# mobile_site_booking    0
# Car_Cancellation       0
# dtype: int64

# %%
import numpy as np

# %%
X = filtered_data.drop(["Car_Cancellation"],axis=1)

# %%
y = filtered_data['Car_Cancellation']

# %%
y_train.reshape(-1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9324\3508729521.py in ?()
# ----> 1 y_train.reshape(-1)
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'reshape'

# %%
X_train,y_train,X_test,y_test=train_test_split(X,y,test_size=.3,random_state=0)

# %%
# Check the shape of your target variable
print(y_train.shape)

# Convert DataFrame or 2D array to 1D array using .ravel()
y_train_1d = y_train.values.ravel()

# Display the shape and head of the reshaped target variable
print(y_train_1d.shape)
print(pd.Series(y_train_1d).head())
# Out:
# (451, 4)
# (1804,)
# 0       1.0
# 1    1147.0
# 2       0.0
# 3       0.0
# 4       1.0
# dtype: float64

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train,y_train)
target_predict_lr = lr.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 3
#       1 from sklearn.linear_model import LogisticRegression
#       2 lr = LogisticRegression()
# ----> 3 lr.fit(X_train,y_train)
#       4 target_predict_lr = lr.predict(X_test)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1207, in LogisticRegression.fit(self, X, y, sample_weight)
#    1204 else:
# ...

# %%
print(y_train.unique())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9324\4166876721.py in ?()
# ----> 1 print(y_train.unique())
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'
